# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/50_Startups.csv')
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
data_set=dataset.rename({'R&D Spend':'RDSp','Administration':'ADM','Marketing Spend':'MKRTS'},axis=1)
data_set
# Out:
#          RDSp        ADM      MKRTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %% [markdown]
# # **EDA**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
dataset.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
dataset[dataset.duplicated()]   #there is no duplicated data
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %% [markdown]
# **Prepare correlation matrix**

# %%
dataset.corr()
# Out:
# <ipython-input-8-c187c74d1e71>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.corr()
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style="darkgrid")
sns.pairplot(dataset)

# %% [markdown]
# ### **Model Building**

# %%
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import influence_plot

# %%
model=smf.ols('Profit~RDSp+ADM+MKRTS',data=data_set).fit()

# %%
#coefficient of Beta values
model.params
# Out:
# Intercept    50122.192990
# RDSp             0.805715
# ADM             -0.026816
# MKRTS            0.027228
# dtype: float64

# %%
#find out t and p values

# %%
model.tvalues ,model.pvalues
# Out:
# (Intercept     7.626218
#  RDSp         17.846374
#  ADM          -0.525507
#  MKRTS         1.655077
#  dtype: float64,
#  Intercept    1.057379e-09
#  RDSp         2.634968e-22
#  ADM          6.017551e-01
#  MKRTS        1.047168e-01
#  dtype: float64)

# %%
np.round(model.pvalues,5)
# Out:
# Intercept    0.00000
# RDSp         0.00000
# ADM          0.60176
# MKRTS        0.10472
# dtype: float64

# %%
# rsquared value
model.rsquared , model.rsquared_adj        #model accuracy is 94.75%
# Out:
# (0.9507459940683246, 0.9475337762901719)

# %%
#when ADM and MKRTS we done it in combine then we didn't find out significant so we need to calculate seperately .

# %%
ML_A=smf.ols('Profit~ADM',data=data_set).fit()

# %%
print(ML_A.tvalues,'/n',ML_A.pvalues)
# Out:
# Intercept    3.040044
# ADM          1.419493
# dtype: float64 /n Intercept    0.003824
# ADM          0.162217
# dtype: float64

# %%
ML_M=smf.ols('Profit~MKRTS',data=data_set).fit()

# %%
print(ML_M.tvalues,'\n',ML_M.pvalues)
#Now we combine both ADM and MKRTS
# Out:
# Intercept    7.808356
# MKRTS        7.802657
# dtype: float64
#  Intercept    4.294735e-10
# MKRTS        4.381073e-10
# dtype: float64

# %%
ML_AM=smf.ols('Profit~ADM+MKRTS',data=data_set).fit()

# %%
ML_AM.tvalues , ML_AM.pvalues
# Out:
# (Intercept    1.142741
#  ADM          2.467779
#  MKRTS        8.281039
#  dtype: float64,
#  Intercept    2.589341e-01
#  ADM          1.729198e-02
#  MKRTS        9.727245e-11
#  dtype: float64)

# %% [markdown]
# # **Model Validation**

# %% [markdown]
# **Two Technique 1) colinearity test 2)Residual test**

# %%
#we need to use varience Inflation factor
#vif=1/(1-R sqr)

# %%
rsq_r=smf.ols('RDSp~ADM+MKRTS',data=data_set).fit().rsquared_adj

# %%
vif_r=1/1-rsq_r
vif_r
# Out:
# 0.42227384467207907

# %%
rsq_a=smf.ols('ADM~RDSp+MKRTS',data=data_set).fit().rsquared_adj
vif_a=1/1-rsq_a
vif_a
# Out:
# 0.887210594949711

# %%
rsq_m=smf.ols('MKRTS~RDSp+ADM',data=data_set).fit().rsquared_adj
vif_m=1/1-rsq_m
vif_m
# Out:
# 0.4480682306833135

# %%
#putting this values in dataframe format then understand clearly
DF={'variables':['RDSp','MKRTS','ADM'],'vif':[vif_r,vif_m,vif_a]}
VIF_values=pd.DataFrame(DF)
VIF_values
# Out:
#   variables       vif
# 0      RDSp  0.422274
# 1     MKRTS  0.448068
# 2       ADM  0.887211

# %%
#Non of the any variable is VIF>20, so No colinearity, so cosider all variables in regression equation

# %%
#2) Residual test
#Test for Normality of Residuals (Q-Q Plot) using residual model (model.resid)
import statsmodels.api as sm

# %%
qq_value=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid<-20000))
# Out:
# [array([49])]

# %%
def standardized_values(vals):return (vals-vals.mean())/vals.std()

# %%
plt.figure(figsize=(8,8))
plt.scatter(standardized_values(model.fittedvalues),standardized_values(model.resid))
plt.title('Residual Plot')
plt.xlabel('standardized fitted values')
plt.ylabel('standardized residual values')
plt.show()

# %%
# Test for errors or Residuals Vs Regressors or independent 'x' variables or predictors
## using Residual Regression Plots code graphics.plot_regress_exog(model,'x',fig)    # exog = x-variable & endog

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'RDSp',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'ADM',fig=fig)
plt.show()

# %%
fig=plt.figure(figsize=(15,8))
sm.graphics.plot_regress_exog(model,'MKRTS',fig=fig)
plt.show()

# %% [markdown]
# **Model deletion Method** ....Checking Outliers or influncer

# %%
# 1. Cook's Distance: If Cook's distance > 1, then it's an outlier
# Get influencers using cook's distance
(c,_)=model.get_influence().cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# Plot the influencers using the stem plot
fig=plt.figure(figsize=(20,7))
plt.stem(np.arange(len(data_set)),np.round(c,5))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
# Index and value of influencer where C>0.5
np.argmax(c) , np.max(c)
# Out:
# (49, 0.2880822927543272)

# %%
# 2. Leverage Value using High Influence Points : Points beyond Leverage_cutoff value are influencers
influence_plot(model)
plt.show()

# %%
# Leverage Cuttoff Value = 3*(k+1)/n ; k = no.of features/columns & n = no. of datapoints
k=data_set.shape[1]
n=data_set.shape[0]
leverage_cutoff = (3*(k+1))/n
leverage_cutoff    #this cutoff and beyond this outliers present
# Out:
# 0.36

# %%
data_set[data_set.index.isin([49])]
# Out:
#     RDSp       ADM     MKRTS       State   Profit
# 49   0.0  116983.8  45173.06  California  14681.4

# %% [markdown]
# **Impoving the model**

# %%
# Discard the data points which are influencers and reassign the row number (reset_index(drop=True))
dataS=data_set.drop(data_set.index[[49]],axis=0).reset_index(drop=True)
dataS
# Out:
#          RDSp        ADM      MKRTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
while np.max(c)>0.5 :
    model=smf.ols("Profit~RDSp+ADM+MKRTS",data=dataS).fit()
    (c,_)=model.get_influence().cooks_distance
    c
    np.argmax(c) , np.max(c)
    dataS=dataS.drop(dataS.index[[np.argmax(c)]],axis=0).reset_index(drop=True)
    dataS
else:
    final_model=smf.ols("Profit~RDSp+ADM+MKRTS",data=dataS).fit()
    final_model.rsquared , final_model.aic
    print("Thus model accuracy is improved to",final_model.rsquared)
    #model Accuracy has ben increased 96.13%
# Out:
# Thus model accuracy is improved to 0.9613162435129847

# %%
final_model.rsquared
# Out:
# 0.9613162435129847

# %%
dataS
# Out:
#          RDSp        ADM      MKRTS       State     Profit
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
# say New data for prediction is
new_data=pd.DataFrame({'RDSp':50000,"ADM":90000,"MKRTS":120000},index=[0])
new_data
# Out:
#     RDSp    ADM   MKRTS
# 0  50000  90000  120000

# %%
# Manual Prediction of Price
final_model.predict(new_data)
# Out:
# 0    92562.444839
# dtype: float64

# %%
pred_y=final_model.predict(dataS)
pred_y   # 90% prediction of profit
# Out:
# 0     190716.676999
# 1     187537.122227
# 2     180575.526396
# 3     172461.144642
# 4     170863.486721
# 5     162582.583177
# 6     157741.338633
# 7     159347.735318
# 8     151328.826941
# 9     154236.846778
# 10    135507.792682
# 11    135472.855621
# 12    129355.599449
# 13    127780.129139
# 14    149295.404796
# 15    145937.941975
# 16    117437.627921
# 17    130408.626295
# 18    129129.234457
# 19    116641.003121
# 20    117097.731866
# 21    117911.019038
# 22    115248.217796
# 23    110603.139045
# 24    114051.073877
# 25    103398.054385
# 26    111547.638935
# 27    114916.165026
# 28    103027.229434
# 29    103057.621761
# 30    100656.410227
# 31     99088.213693
# 32    100325.741335
# 33     98962.303136
# 34     90552.307809
# 35     91709.288672
# 36     77080.554255
# 37     90722.503244
# 38     71433.021956
# 39     85147.375646
# 40     76625.510303
# 41     76492.145175
# 42     72492.394974
# 43     62592.049718
# 44     67025.731107
# ...

# %%
DP={'Prep_Models':['Model','Final_Model'],'Rsquared':[model.rsquared,final_model.rsquared]}
table=pd.DataFrame(DP)
table
# Out:
#    Prep_Models  Rsquared
# 0        Model  0.950746
# 1  Final_Model  0.961316
