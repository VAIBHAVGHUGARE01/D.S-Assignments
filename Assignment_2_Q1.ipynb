# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Measure_x=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])
Measure_x
# Out:
# 0     24.23
# 1     25.53
# 2     25.41
# 3     24.14
# 4     29.62
# 5     28.25
# 6     25.81
# 7     24.39
# 8     40.26
# 9     32.95
# 10    91.36
# 11    25.99
# 12    39.42
# 13    26.71
# 14    35.00
# dtype: float64

# %%
Name_of_company=['Allied signal','Bankers trust','General Mill','ITT Industries','JP Morgan','Lehman Brothers','JW Marriot','MCI','Merril','MS','Morgan Stanley','Sun Microsoft','Travelers','US airways','Warner-Lambert']

# %%
#pie plot
plt.figure(figsize=(6,8))
plt.pie(Measure_x,labels=Name_of_company,autopct='%1.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Boxplot to find outliers
sns.boxplot(Measure_x)
# Out:
# <Axes: >

# %%
Measure_x.mean()
# Out:
# 33.27133333333333

# %%
Measure_x.var()
# Out:
# 287.1466123809524

# %%
Measure_x.std()
# Out:
# 16.945400921222028
