# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import chi2_contingency

# %%
data=pd.read_csv("/content/BuyerRatio.csv")
data
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
df=np.array([[50,142,131,70],[435,1523,1356,750]])
df
# Out:
# array([[  50,  142,  131,   70],
#        [ 435, 1523, 1356,  750]])

# %%
df1=pd.DataFrame(df,index=['Male','Female'],columns=['East','west','North','South'])
df1
# Out:
#         East  west  North  South
# Male      50   142    131     70
# Female   435  1523   1356    750

# %%
#Chi2 contingency test

# %%
chi2_contingency(df)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
#p>α ...p= 0.6603 , α=0.05
#so we can not reject null hypothesis.The variables are independent , there is no relationship between the catagorical variable,
